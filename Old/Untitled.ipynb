# %%
from google.cloud import storage
import pandas as pd

bucket_name = "bank-churn-analytics"
file_name = "Bank Customer Churn Prediction.csv"

client = storage.Client()
bucket = client.bucket(bucket_name)
blob = bucket.blob(file_name)

df = pd.read_csv(blob.open("r"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from google.cloud import storage
#       2 import pandas as pd
#       4 bucket_name = "bank-churn-analytics"
#
# ImportError: cannot import name 'storage' from 'google.cloud' (unknown location)

# %%
# !pip install google-cloud-storage
# Out:
# Collecting google-cloud-storage
#   Obtaining dependency information for google-cloud-storage from https://files.pythonhosted.org/packages/1b/bd/a89eaebd2f9db5f92ddcc8e4f23c266be1dbd11058bb83451d8dd029f34c/google_cloud_storage-3.12.0-py3-none-any.whl.metadata
#   Downloading google_cloud_storage-3.12.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (2.52.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (2.6.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (2.9.0)
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (2.31.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.6.0 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-cloud-storage) (1.8.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.75.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (6.33.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage) (1.28.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.2.8)
# Requirement already satisfied: cryptography>=38.0.3 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage) (46.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.22.0->google-cloud-storage) (2025.10.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (2.0.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (0.4.8)
# Requirement already satisfied: pycparser in /Users/jihyechoi/anaconda3/lib/python3.11/site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.26.1->google-cloud-storage) (2.23)
# Downloading google_cloud_storage-3.12.0-py3-none-any.whl (340 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 340.6/340.6 kB 5.1 MB/s eta 0:00:00 MB/s eta 0:00:01
# Installing collected packages: google-cloud-storage
# Successfully installed google-cloud-storage-3.12.0
